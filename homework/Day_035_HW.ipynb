# %% [markdown]
# # Day_035

# %% [markdown]
# ### 練習時間
# 相信大家對回歸問題及分類問題都有初步的了解。今天的作業希望大家搜尋有關 multi-label 的案例問題。下圖是電影 "奇異博士" 的分類。可以看到同時有 "Action", "Adventure", "Fantasy" 的類別存在，代表這是個多標籤的問題。

# %% [markdown]
# ![image](https://cdn-images-1.medium.com/max/1000/1*r0gYXMSQf5VhdMyl2bRDyg.png)

# %% [markdown]
# #### 請搜尋目標為多標籤問題 (Multi-label) 的機器學習案例，了解其資料來源、目標以及評估指標為何

# %% [markdown]
# 目前有很多關於多標籤的學習演算法，依據解決問題的角度，這些演算法可以分為兩大類：一是基於問題轉化（Problem Transformation）的方法，二是基於演算法適應的方法和演算法適應方法（Algorithm Adaptation）。基於問題轉化的多標記分類是轉化問題資料，使之適用現有演算法；基於演算法適應的方法是指標對某一特定的演算法進行擴充套件，從而能夠直接處理多標記資料，改進演算法，適應資料。基於這兩種思想，目前已經有多種相對成熟的演算法被提出。
# #### 參考網站：程式前沿 https://codertw.com/%E7%A8%8B%E5%BC%8F%E8%AA%9E%E8%A8%80/404276/#outline__7_5
#
# * 案例：音訊分類 - 歌曲
# * 資料來源：http://lpis.csd.auth.gr/publications/tsoumakas-ismir08.pdf
# * 目標：不同音樂情感( amazed-surprised, happy-pleased, relaxing-calm, quiet-still, sad-lonely, angry-fearful)
# * 評估指標：準確率(F1, AUC) multilabel classification algorithms: binary relevance (BR), label powerset (LP), random k-labelsets (RAKEL) and multilabel k-nearest neighbor (MLkNN)
#
# 一首歌曲可能因為情感、趨勢、曲風等因素而被分為多個類別

# %%
from IPython.display import Image
Image(filename = 'D:/Coding Project/GitHub/ML100-Days/kkbox_songs.jpg', width = 300)
